# %% [markdown]
# <img src="The Sparks Foundation logo.png" width="190" height="100" align = "right">
#
# # <font face='Cooper Black' color='282E58' size = 20><u><b>THE SPARKS FOUNDATION</b></u></font>
# # <font face='Cooper Black' size = 6>@GRIP June 2022</font>
#
# # <font face='Cooper Black' color='282E58' size = 6>Data Science and Business Analytics Intern</font>
#
# ## <font face='Cooper Black' color='40610f' size = 6><b>Name: Vishwajeet Kamble</b></font>
#
# ### <font face='Cooper Black' color='40610f' size = 5>LinkedIn: https://www.linkedin.com/in/-vishwajeet-kamble-</font>
# ### <font face='Cooper Black' color='40610f' size = 5>GitHub: https://github.com/vishwajeet-kamble</font>
#
#
# ### <font size = 16 face = 'Broadway' color='red'><center><u><i>Task 2</i></u></center></font>

# %% [markdown]
# ###  <i>Exploratory Data Analysis - Terrorism ( Intermediate  )</i>
# ### Dataset Link : https://bit.ly/2TK5Xn5
# ### <font color='blue'>Objective</font>:
# ● Perform ‘Exploratory Data Analysis’ on dataset  ‘Global Terrorism’
#
# ● As a security/defense analyst, try to find out the hot zone of terrorism.
#
# ● What all security issues and insights you can derive by EDA?

# %% [markdown]
# ### Importing Libraries

# %%
#Importing important libraries

import warnings
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
#reading the data file using pandas library
dataset = pd.read_csv('globalterrorismdb_0718dist.csv',encoding = 'ISO-8859-1')
# Out:
# C:\Users\Kamble\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### Performing EDA

# %%
display(dataset)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       1.970000e+11   1970       7     2        NaN         0        NaN
# 1       1.970000e+11   1970       0     0        NaN         0        NaN
# 2       1.970010e+11   1970       1     0        NaN         0        NaN
# 3       1.970010e+11   1970       1     0        NaN         0        NaN
# 4       1.970010e+11   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
## Columns in our Dataset

print('These are the columns in our dataset :\n')
print(dataset.columns)
# Out:
# These are the columns in our dataset :
#
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ### Renaming Columns

# %%
dataset.rename(columns={'iyear':'Year','imonth':'Month','extended':'Extended','iday':'Day','country_txt':'Country',
                        'provstate':'state','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target',
                        'nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                        'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %% [markdown]
# ### Taking Important Columns for EDA

# %%
dataset = dataset[['Year','Month','Extended','Day','Country','state','Region','city','latitude','longitude',
                   'AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %% [markdown]
# ### Check for Duplicates Values

# %%
duplicate = dataset[dataset.duplicated()]
print('There are ' + str(len(duplicate)) + ' duplicate values in the dataset.')
print('\nAnd that are : ')
duplicate
# Out:
# There are 9497 duplicate values in the dataset.
#
# And that are :
#         Year  Month  Extended  Day        Country         state  \
# 68      1970      2         0   16  United States    California
# 88      1970      2         0   23  United States      Nebraska
# 89      1970      2         0   23  United States      Nebraska
# 90      1970      2         0   23  United States      Nebraska
# 337     1970      6         1    9         Jordan         Amman
# ...      ...    ...       ...  ...            ...           ...
# 181397  2017     12         0   18       Pakistan   Balochistan
# 181431  2017     12         0   20    Philippines   Maguindanao
# 181587  2017     12         0   27          India  Chhattisgarh
# 181634  2017     12         0   29         Israel      Southern
# 181657  2017     12         0   30          Kenya       Garissa
#
#                             Region              city   latitude   longitude  \
# 68                   North America          Berkeley  37.874043 -122.280022
# 88                   North America  South Sioux City  42.470310  -96.413949
# 89                   North America  South Sioux City  42.470310  -96.413949
# 90                   North America  South Sioux City  42.470310  -96.413949
# 337     Middle East & North Africa             Amman  31.950001   35.933331
# ...                            ...               ...        ...         ...
# 181397                  South Asia           Mangoli  28.466810   68.274078
# 181431              Southeast Asia         Tamontaka   7.172751  124.229664
# 181587                  South Asia          Basaguda  18.561113   80.920395
# 181634  Middle East & North Africa           Unknown  31.506981   34.718904
# 181657          Sub-Saharan Africa             Ijara  -1.595245   40.514259
#
#                                  AttackType  Killed  Wounded  \
# 68                        Bombing/Explosion     0.0      0.0
# 88                        Bombing/Explosion     0.0      0.0
# 89                        Bombing/Explosion     0.0      0.0
# 90                        Bombing/Explosion     0.0      0.0
# 337     Hostage Taking (Barricade Incident)     0.0      0.0
# ...                                     ...     ...      ...
# 181397                    Bombing/Explosion     0.0      0.0
# 181431                    Bombing/Explosion     0.0      0.0
# 181587                    Bombing/Explosion     0.0      0.0
# 181634                    Bombing/Explosion     0.0      0.0
# 181657                        Armed Assault     0.0      0.0
#
#                                                    Target  \
# 68                                       department store
# 88      Power Transmission Pole in the Dakota City/Sio...
# 89      Power Transmission Pole in the Dakota City/Sio...
# 90      Power Transmission Pole in the Dakota City/Sio...
# 337                                                Hotels
# ...                                                   ...
# 181397                                  Electricity Tower
# 181431                                         Checkpoint
# 181587                                            Unknown
# 181634                                            Unknown
# 181657                                     Police Station
#
#                                                   Summary  \
# 68                                                    NaN
# 88      2/23/1970: In a series of related attacks, unk...
# 89      2/23/1970: In a series of related attacks, unk...
# 90      2/23/1970: In a series of related attacks, unk...
# 337                                                   NaN
# ...                                                   ...
# 181397  12/18/2017: An explosive device detonated near...
# 181431  12/20/2017: Assailants threw a grenade at a mi...
# 181587  12/00/2017: Sometime between December 24, 2017...
# 181634  12/29/2017: Assailants in Gaza fired a rocket ...
# 181657  12/30/2017: Assailants raided a police station...
#
#                                                     Group Target_type  \
# 68                                                Unknown    Business
# 88                                               Strikers   Utilities
# 89                                               Strikers   Utilities
# 90                                               Strikers   Utilities
# 337     Popular Front for the Liberation of Palestine ...    Business
# ...                                                   ...         ...
# 181397                       Baloch Republican Army (BRA)   Utilities
# 181431         Bangsamoro Islamic Freedom Movement (BIFM)    Military
# 181587                                            Unknown     Unknown
# 181634                                            Unknown     Unknown
# 181657                                         Al-Shabaab      Police
#
#        Weapon_type                                             Motive
# 68      Explosives                                                NaN
# 88      Explosives  The attack occurred during the violent Iowa Be...
# 89      Explosives  The attack occurred during the violent Iowa Be...
# 90      Explosives  The attack occurred during the violent Iowa Be...
# 337       Firearms                                                NaN
# ...            ...                                                ...
# 181397  Explosives                                                NaN
# 181431  Explosives  The specific motive is unknown; however, sourc...
# 181587  Explosives                                                NaN
# 181634  Explosives                                                NaN
# 181657    Firearms                                                NaN
#
# [9497 rows x 19 columns]

# %%
dataset.drop_duplicates(inplace = True)

# %%
duplicate = dataset[dataset.duplicated()]
print('There are ' + str(len(duplicate)) + ' duplicate values in the dataset.')
print('\nAs We can see : ')
duplicate
# Out:
# There are 0 duplicate values in the dataset.
#
# As We can see :
# Empty DataFrame
# Columns: [Year, Month, Extended, Day, Country, state, Region, city, latitude, longitude, AttackType, Killed, Wounded, Target, Summary, Group, Target_type, Weapon_type, Motive]
# Index: []

# %% [markdown]
# ### Rows and Columns in our Dataset

# %%
dataset.head()
# Out:
#    Year  Month  Extended  Day             Country    state  \
# 0  1970      7         0    2  Dominican Republic      NaN
# 1  1970      0         0    0              Mexico  Federal
# 2  1970      1         0    0         Philippines   Tarlac
# 3  1970      1         0    0              Greece   Attica
# 4  1970      1         0    0               Japan  Fukouka
#
#                         Region           city   latitude   longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# 4                    East Asia        Fukouka  33.580412  130.396361
#
#                        AttackType  Killed  Wounded                   Target  \
# 0                   Assassination     1.0      0.0             Julio Guzman
# 1     Hostage Taking (Kidnapping)     0.0      0.0  Nadine Chaval, daughter
# 2                   Assassination     1.0      0.0                 Employee
# 3               Bombing/Explosion     NaN      NaN             U.S. Embassy
# 4  Facility/Infrastructure Attack     NaN      NaN           U.S. Consulate
#
#   Summary                               Group                  Target_type  \
# 0     NaN                              MANO-D  Private Citizens & Property
# 1     NaN  23rd of September Communist League      Government (Diplomatic)
# 2     NaN                             Unknown          Journalists & Media
# 3     NaN                             Unknown      Government (Diplomatic)
# 4     NaN                             Unknown      Government (Diplomatic)
#
#   Weapon_type Motive
# 0     Unknown    NaN
# 1     Unknown    NaN
# 2     Unknown    NaN
# 3  Explosives    NaN
# 4  Incendiary    NaN

# %%
## Rows and Columns in our Dataset

Shape = dataset.shape
print(Shape,'\n')

print('There are ' +str(dataset.shape[0]) + ' number of rows and ' + str(dataset.shape[1]) + ' columns in our dataset after removing Duplicates.')
# Out:
# (172194, 19)
#
# There are 172194 number of rows and 19 columns in our dataset after removing Duplicates.

# %% [markdown]
# ### Finding Null Values

# %%
## Null/Na/Nan count of Dataset

dataset.isnull().sum()
# Out:
# Year                0
# Month               0
# Extended            0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4011
# longitude        4012
# AttackType          0
# Killed           9434
# Wounded         15268
# Target            545
# Summary         59093
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         122285
# dtype: int64

# %%
## Datatypes of Dataset

dataset.dtypes
# Out:
# Year             int64
# Month            int64
# Extended         int64
# Day              int64
# Country         object
# state           object
# Region          object
# city            object
# latitude       float64
# longitude      float64
# AttackType      object
# Killed         float64
# Wounded        float64
# Target          object
# Summary         object
# Group           object
# Target_type     object
# Weapon_type     object
# Motive          object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172194 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         172194 non-null  int64
#  1   Month        172194 non-null  int64
#  2   Extended     172194 non-null  int64
#  3   Day          172194 non-null  int64
#  4   Country      172194 non-null  object
#  5   state        171773 non-null  object
#  6   Region       172194 non-null  object
#  7   city         171760 non-null  object
#  8   latitude     168183 non-null  float64
#  9   longitude    168182 non-null  float64
#  10  AttackType   172194 non-null  object
#  11  Killed       162760 non-null  float64
#  12  Wounded      156926 non-null  float64
#  13  Target       171649 non-null  object
#  14  Summary      113101 non-null  object
#  15  Group        172194 non-null  object
#  16  Target_type  172194 non-null  object
#  17  Weapon_type  172194 non-null  object
#  18  Motive       49909 non-null   object
# dtypes: float64(4), int64(4), object(11)
# memory usage: 26.3+ MB

# %%
dataset.describe()
# Out:
#                 Year          Month       Extended            Day  \
# count  172194.000000  172194.000000  172194.000000  172194.000000
# mean     2003.051192       6.470138       0.047057      15.517219
# std        13.191078       3.391790       0.211762       8.814156
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       0.000000       8.000000
# 50%      2009.000000       6.000000       0.000000      15.000000
# 75%      2014.000000       9.000000       0.000000      23.000000
# max      2017.000000      12.000000       1.000000      31.000000
#
#             latitude     longitude         Killed        Wounded
# count  168183.000000  1.681820e+05  162760.000000  156926.000000
# mean       23.777820 -4.829756e+02       2.508245       3.318915
# std        18.297104  2.101583e+05      11.824490      36.892726
# min       -53.154613 -8.618590e+07       0.000000       0.000000
# 25%        11.840929  7.398917e+00       0.000000       0.000000
# 50%        31.528200  4.352332e+01       1.000000       0.000000
# 75%        34.666667  6.895731e+01       2.000000       2.000000
# max        74.633553  1.793667e+02    1570.000000    8191.000000

# %%
## Correlation in Dataset

dataset.corr()
# Out:
#                Year     Month  Extended       Day  latitude  longitude  \
# Year       1.000000 -0.002351  0.086551  0.017998  0.152213   0.004103
# Month     -0.002351  1.000000 -0.000950  0.005482 -0.014204  -0.003977
# Extended   0.086551 -0.000950  1.000000 -0.003855 -0.029708   0.000545
# Day        0.017998  0.005482 -0.003855  1.000000  0.002962  -0.002341
# latitude   0.152213 -0.014204 -0.029708  0.002962  1.000000   0.001549
# longitude  0.004103 -0.003977  0.000545 -0.002341  0.001549   1.000000
# Killed     0.010017  0.003319  0.025812 -0.004230 -0.020985  -0.000543
# Wounded    0.013011  0.002985 -0.007371 -0.001412  0.015480   0.000233
#
#              Killed   Wounded
# Year       0.010017  0.013011
# Month      0.003319  0.002985
# Extended   0.025812 -0.007371
# Day       -0.004230 -0.001412
# latitude  -0.020985  0.015480
# longitude -0.000543  0.000233
# Killed     1.000000  0.534828
# Wounded    0.534828  1.000000

# %% [markdown]
# ### Country

# %%
## Country

print(dataset['Country'].unique(),'\n')

print('Total Countries :\n',len(dataset['Country'].unique()))
# Out:
# ['Dominican Republic' 'Mexico' 'Philippines' 'Greece' 'Japan'
#  'United States' 'Uruguay' 'Italy' 'East Germany (GDR)' 'Ethiopia'
#  'Guatemala' 'Venezuela' 'West Germany (FRG)' 'Switzerland' 'Jordan'
#  'Spain' 'Brazil' 'Egypt' 'Argentina' 'Lebanon' 'Ireland' 'Turkey'
#  'Paraguay' 'Iran' 'United Kingdom' 'Colombia' 'Bolivia' 'Nicaragua'
#  'Netherlands' 'Belgium' 'Canada' 'Australia' 'Pakistan' 'Zambia' 'Sweden'
#  'Costa Rica' 'South Yemen' 'Cambodia' 'Israel' 'Poland' 'Taiwan' 'Panama'
#  'Kuwait' 'West Bank and Gaza Strip' 'Austria' 'Czechoslovakia' 'India'
#  'France' 'South Vietnam' 'Brunei' 'Zaire'
#  "People's Republic of the Congo" 'Portugal' 'Algeria' 'El Salvador'
#  'Thailand' 'Haiti' 'Sudan' 'Morocco' 'Cyprus' 'Myanmar' 'Afghanistan'
#  'Peru' 'Chile' 'Honduras' 'Yugoslavia' 'Ecuador' 'New Zealand' 'Malaysia'
#  'Singapore' 'Botswana' 'Jamaica' 'Chad' 'North Yemen' 'Andorra' 'Syria'
#  'South Korea' 'United Arab Emirates' 'South Africa' 'Kenya' 'Iraq'
#  'Somalia' 'Tanzania' 'Sri Lanka' 'Namibia' 'Bahamas' 'Nigeria' 'Barbados'
#  'Trinidad and Tobago' 'Bangladesh' 'Angola' 'Mauritania' 'Saudi Arabia'
#  'Djibouti' 'Indonesia' 'Malta' 'Rhodesia' 'Soviet Union' 'Denmark'
#  'Western Sahara' 'Guyana' 'Mozambique' 'Tunisia' 'Uganda' 'Norway'
#  'Lesotho' 'Gabon' 'Libya' 'Bahrain' 'Hong Kong' 'Senegal' 'Zimbabwe'
#  'Guinea' 'Grenada' 'New Hebrides' 'Belize' 'Guadeloupe' 'Martinique'
#  'Vatican City' 'Albania' 'Central African Republic' 'Seychelles'
#  'Dominica' 'Qatar' 'Bulgaria' 'Suriname' 'Swaziland' 'Luxembourg'
#  'Iceland' 'French Guiana' 'Falkland Islands' 'Burkina Faso'
#  'New Caledonia' 'Romania' 'Niger' 'Nepal' 'Togo' 'Finland' 'Fiji' 'Ghana'
#  'Maldives' 'Mauritius' 'Hungary' 'Laos' 'Papua New Guinea' 'China'
#  'Liberia' 'Republic of the Congo' 'Mali' 'Germany' 'Yemen' 'Rwanda'
#  'Sierra Leone' 'Cameroon' 'Cuba' 'Croatia' 'Georgia' 'Azerbaijan'
#  'Madagascar' 'Lithuania' 'Burundi' 'Ukraine' 'Moldova' 'Armenia' 'Russia'
#  'Ivory Coast' 'Kazakhstan' 'Antigua and Barbuda' 'Bosnia-Herzegovina'
#  'Equatorial Guinea' 'Tajikistan' 'Malawi' 'Uzbekistan' 'Latvia' 'Estonia'
#  'Vietnam' 'Comoros' 'Benin' 'Slovak Republic' 'Macedonia'
#  'Wallis and Futuna' 'Belarus' 'Czech Republic' 'Slovenia' 'Gambia'
#  'North Korea' 'Eritrea' 'St. Kitts and Nevis' 'French Polynesia' 'Macau'
#  'Kyrgyzstan' 'Vanuatu' 'Democratic Republic of the Congo' 'Kosovo'
#  'Solomon Islands' 'East Timor' 'St. Lucia' 'Guinea-Bissau' 'Montenegro'
#  'International' 'Turkmenistan' 'Serbia-Montenegro' 'Bhutan' 'Serbia'
#  'South Sudan']
#
# Total Countries :
#  205

# %% [markdown]
# ### DESTRUCTIVE FEATURES

# %%
#DESTRUCTIVE FEATURES


print("Country with the most attacks:",dataset['Country'].value_counts().idxmax())

print("City with the most attacks:",dataset['city'].value_counts().index[1]) #as first entry is 'unknown'

print("Region with the most attacks:",dataset['Region'].value_counts().idxmax())

print("Year with the most attacks:",dataset['Year'].value_counts().idxmax())

print("Month with the most attacks:",dataset['Month'].value_counts().idxmax())

print("Group with the most attacks:",dataset['Group'].value_counts().index[1])

print("Most Attack Types:",dataset['AttackType'].value_counts().idxmax())
# Out:
# Country with the most attacks: Iraq
# City with the most attacks: Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %%
pd.crosstab(dataset.Year, dataset.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ### Number of Terrorist Activities each Year

# %%
#Number of Terrorist Activities each Year

plt.subplots(figsize=(15,6))
sns.countplot('Year',data=dataset,palette='RdYlGn_r',edgecolor=sns.color_palette("YlOrBr", 10))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()
# Out:
# C:\Users\Kamble\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#History of the Worst Terror Attacks in Heatmap using Plotly

dataset['Wounded'] =dataset['Wounded'].fillna(0).astype(int)
dataset['Killed'] = dataset['Killed'].fillna(0).astype(int)
dataset['casualities'] = dataset['Killed'] + dataset['Wounded']

# %%
#Values are sorted by the top 40 worst terror attacks as to keep the heatmap simple and easy to visualize

dataset1 = dataset.sort_values(by='casualities',ascending=False)[:40]

# %%
heat=dataset1.pivot_table(index='Country',columns='Year',values='casualities')
heat.fillna(0,inplace=True)

# %%
dataset.Country.value_counts()[:15]
# Out:
# Iraq              23459
# Pakistan          13795
# Afghanistan       12512
# India             11585
# Colombia           7504
# Philippines        6771
# Peru               5049
# United Kingdom     4998
# El Salvador        4305
# Somalia            4121
# Turkey             4086
# Nigeria            3828
# Thailand           3740
# Yemen              3305
# Spain              3072
# Name: Country, dtype: int64

# %%
#Top Countries affected by Terror Attacks¶

plt.subplots(figsize=(15,6))
sns.barplot(dataset['Country'].value_counts()[:15].index,dataset['Country'].value_counts()[:15].values,palette='Blues_d')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()
# Out:
# C:\Users\Kamble\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Now to visualize the top four countries that have suffered the most using bubble charts in Plotly¶

terror_dataset =dataset[(dataset['Group'] != 'Unknown') & (dataset['casualities'] > 50)]
terror_dataset.head()
# Out:
#       Year  Month  Extended  Day         Country             state  \
# 1200  1972      3         0    4  United Kingdom  Northern Ireland
# 1314  1972      5         0   30          Israel           Central
# 1789  1973      3         0    8  United Kingdom           England
# 1972  1973      8         0    5          Greece            Attica
# 2138  1973     12         1   17           Italy             Lazio
#
#                           Region     city   latitude  longitude  \
# 1200              Western Europe  Belfast  54.607712  -5.956210
# 1314  Middle East & North Africa      Lod  32.004361  34.888229
# 1789              Western Europe   London  51.504387  -0.140041
# 1972              Western Europe   Athens  37.997490  23.762728
# 2138              Western Europe     Rome  41.890961  12.490069
#
#                                AttackType  Killed  Wounded  \
# 1200                    Bombing/Explosion       2      130
# 1314                    Bombing/Explosion      26       72
# 1789                    Bombing/Explosion       1      238
# 1972                    Bombing/Explosion       5       55
# 2138  Hostage Taking (Barricade Incident)      30       50
#
#                                               Target Summary  \
# 1200  Janet Bereen, 21 and Anne Owens, 22, Catholics     NaN
# 1314                               Aircraft Terminal     NaN
# 1789                                  Court Building     NaN
# 1972                                      TWA Lounge     NaN
# 2138            Pan Am Lounge and Loading Pan Am 707     NaN
#
#                             Group           Target_type Weapon_type Motive  \
# 1200  Irish Republican Army (IRA)              Business  Explosives    NaN
# 1314      Japanese Red Army (JRA)   Airports & Aircraft    Firearms    NaN
# 1789  Irish Republican Army (IRA)  Government (General)  Explosives    NaN
# 1972              Black September   Airports & Aircraft    Firearms    NaN
# 2138              Black September   Airports & Aircraft    Firearms    NaN
#
#       casualities
# 1200          132
# 1314           98
# 1789          239
# 1972           60
# 2138           80

# %%
terror_dataset = terror_dataset.sort_values(['Region', 'Country'])

# %%
#It is best to always check for null values and drop the features that are not needed. Atleast it can execute much faster¶

terror_dataset.isnull().sum()
# Out:
# Year              0
# Month             0
# Extended          0
# Day               0
# Country           0
# state             3
# Region            0
# city              1
# latitude         62
# longitude        62
# AttackType        0
# Killed            0
# Wounded           0
# Target            9
# Summary         514
# Group             0
# Target_type       0
# Weapon_type       0
# Motive         1054
# casualities       0
# dtype: int64

# %%
terror_dataset = terror_dataset.drop(['latitude','longitude','Summary','Motive','Target'],axis=1)

# %%
terror_dataset = terror_dataset.dropna(subset=['city'])

# %%
#Methods of attack

plt.figure(figsize=(13,6))
sns.countplot(dataset['AttackType'],data=dataset,order=dataset['AttackType'].value_counts().index,
              palette='hot')
plt.xticks(rotation=90)
plt.xlabel('Method')
plt.title('Method of Attack')
plt.show()
# Out:
# C:\Users\Kamble\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Country and region

fig,axes = plt.subplots(figsize=(16,11),nrows=1,ncols=2)
sns.barplot(x = dataset['Country'].value_counts()[:20].values, y = dataset['Country'].value_counts()[:20].index, 
            ax=axes[0],palette = 'magma');
axes[0].set_title('Terrorist Attacks per Country')
sns.barplot(x=dataset['Region'].value_counts().values,y=dataset['Region'].value_counts().index,
            ax=axes[1])
axes[1].set_title('Terrorist Attacks per Region')
fig.tight_layout()
plt.show()

# %%
#Most active organizations

plt.subplots(figsize=(11,10))
sns.barplot(y=dataset['Group'].value_counts()[1:12].index,x=dataset['Group'].value_counts()[1:12].values,
           palette='copper')
plt.title('Most Active Terrorist Organizations')
plt.show()

# %%
#Most affected targets

plt.subplots(figsize=(15,7))
sns.barplot(y=dataset['Target_type'].value_counts().index,x=dataset['Target_type'].value_counts().values,
           palette='tab10')
plt.title('Most Affected Targets')
plt.show()

# %%
#Before and after the War on Terror

#After the 9/11 attacks in New York City, the US-led War on Terror was launched with the goal to distinguish terrorism primarily in the Middle East. Here, it is shown as a turning point for activity patterns in each region.


dataset_after = dataset[dataset['Year']>=2001]
fig,ax = plt.subplots(figsize=(15,10),nrows=2,ncols=1)
ax[0] = pd.crosstab(dataset.Year,dataset.Region).plot(ax=ax[0])
ax[0].set_title('Change in Regions per Year')
ax[0].legend(loc='center left',bbox_to_anchor = (1,0.5))
ax[0].vlines(x=2001,ymin=0,ymax=7000,colors='red',linestyles='--')
pd.crosstab(dataset_after.Year,dataset_after.Region).plot.bar(stacked=True,ax=ax[1])
ax[1].set_title('After Declaration of War on Terror (2001-2017)')
ax[1].legend(loc='center left',bbox_to_anchor = (1,0.5))
plt.show()

# %%
#The shift from Western Europe to Eastern Europe

fig,axes = plt.subplots(figsize=(15,6))
sns.lineplot(dataset[dataset['Region']=='Western Europe']['Year'].value_counts().index,
             dataset[dataset['Region']=='Western Europe']['Year'].value_counts().values)
sns.lineplot(dataset[dataset['Region']=='Eastern Europe']['Year'].value_counts().index,
             dataset[dataset['Region']=='Eastern Europe']['Year'].value_counts().values)
plt.xlabel('Year')
plt.xticks(np.arange(1970,2017,5))
plt.xlim(1970,2017)
plt.ylabel('Number of Attacks')
plt.title('Western vs Eastern Europe')
axes.legend(labels=['Western Europe','Eastern Europe'])
plt.show()
# Out:
# C:\Users\Kamble\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Kamble\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig,ax = plt.subplots(figsize=(15,6))
russia = dataset[(dataset['Country']=='Russia') & (dataset['Year'].between(1991,2017,inclusive=True))]['Year'].value_counts()
ukraine = dataset[(dataset['Country']=='Ukraine') & (dataset['Year'].between(1991,2017,inclusive=True))]['Year'].value_counts()
rest_east = dataset[(dataset['Country']!='Russia') & (dataset['Country']!='Ukraine')
               & (dataset['Region']=='Eastern Europe')& (dataset['Year'].between(1991,2017,inclusive=True))]['Year'].value_counts()
sns.lineplot(x=russia.index,y=russia.values)
sns.lineplot(x=ukraine.index,y=ukraine.values)
sns.lineplot(x=rest_east.index,y=rest_east.values)
plt.xticks(np.arange(1991,2017,1))
plt.xlim(1991,2017)
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Russia and Ukraine vs Rest of Eastern Europe')
ax.legend(labels=['Russia','Ukraine','Rest of Eastern Europe'])
plt.show()
# Out:
# C:\Users\Kamble\AppData\Local\Temp/ipykernel_33196/2087188467.py:2: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   russia = dataset[(dataset['Country']=='Russia') & (dataset['Year'].between(1991,2017,inclusive=True))]['Year'].value_counts()
# C:\Users\Kamble\AppData\Local\Temp/ipykernel_33196/2087188467.py:3: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   ukraine = dataset[(dataset['Country']=='Ukraine') & (dataset['Year'].between(1991,2017,inclusive=True))]['Year'].value_counts()
# C:\Users\Kamble\AppData\Local\Temp/ipykernel_33196/2087188467.py:5: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   & (dataset['Region']=='Eastern Europe')& (dataset['Year'].between(1991,2017,inclusive=True))]['Year'].value_counts()

# %% [markdown]
# ***Are extended attacks more lethal?***

# %% [markdown]
# ***Extended attacks are defined as events that last longer than 24 hours. Does a longer timeframe mean a higher rate of casualties? Lets first look at which methods of attack tend to be extended or unextended.***

# %%
fig,ax = plt.subplots(figsize=(15,6),nrows=1,ncols=2)
ax[0]=dataset[dataset['Extended']==1].groupby('AttackType').count()['Extended'].sort_values().plot.barh(color='red',ax=ax[0])
ax[1]=dataset[dataset['Extended']==0].groupby('AttackType').count()['Extended'].sort_values().plot.barh(color='blue',ax=ax[1])
ax[0].set_title('Number of Extended Attacks')
ax[0].set_ylabel('Method')
ax[1].set_title('Number of Unextended Attacks')
ax[1].set_ylabel('Method')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion
# * Terrorist acts in the Middle East and northern Africa have been seen to have fatal consequences.
# * The Middle East and North Africa are seen to be the places of serious terrorist attacks.
# * In addition, even though there is a perception that Muslims are supporters of terrorism, Muslims are the people who are most damaged by terrorist attacks.
# * If you look at the graphics, it appears that Iraq, Afghanistan and Pakistan are the most damaged countries.
# * All of these countries are Muslim countries.
