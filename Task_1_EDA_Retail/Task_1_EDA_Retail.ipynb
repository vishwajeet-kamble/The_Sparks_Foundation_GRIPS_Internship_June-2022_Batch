# %% [markdown]
# <img src="The Sparks Foundation logo.png" width="190" height="100" align = "right">
#
# # <font face='Cooper Black' color='282E58' size = 20><u><b>THE SPARKS FOUNDATION</b></u></font>
# # <font face='Cooper Black' size = 6>@GRIP June 2022</font>
#
# # <font face='Cooper Black' color='282E58' size = 6>Data Science and Business Analytics Intern</font>
#
# ## <font face='Cooper Black' color='40610f' size = 6><b>Name: Vishwajeet Kamble</b></font>
#
# ### <font face='Cooper Black' color='40610f' size = 5>LinkedIn: https://www.linkedin.com/in/-vishwajeet-kamble-</font>
# ### <font face='Cooper Black' color='40610f' size = 5>GitHub: https://github.com/vishwajeet-kamble</font>
#
# ### <font size = 16 face = 'Broadway' color='red'><center><u><i>Task 1</i></u></center></font>
#
# ### <i>Exploratory Data Analysis - Retail ( Level Beginner )</i>
#
# * Perform ‘Exploratory Data Analysis’ on dataset  ‘SampleSuperstore’
# * As a business manager, try to find out the weak areas where you can work to make more profit.
# * Dataset: https://bit.ly/3i4rbWl

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Loading The Dataset

# %%
df = pd.read_csv('SampleSuperstore.csv')

# %% [markdown]
# ### Performing Exploratory Data Analysis (EDA)

# %%
## Displaying Dataset 
# Top 5 and Bottom 5 Rows are been Diplayed

display(df)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ### Check for Duplicates Values

# %%
duplicate = df[df.duplicated()]
print('There are ' + str(len(duplicate)) + ' duplicate values in the dataset.')
print('\nAnd that are : ')
duplicate
# Out:
# There are 17 duplicate values in the dataset.
#
# And that are :
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# ...

# %% [markdown]
# ### Removing Duplicate Values

# %%
df.drop_duplicates(inplace = True)

# %%
duplicate = df[df.duplicated()]
print('There are ' + str(len(duplicate)) + ' duplicate values in the dataset.')
print('\nAs We can see : ')
duplicate
# Out:
# There are 0 duplicate values in the dataset.
#
# As We can see :
# Empty DataFrame
# Columns: [Ship Mode, Segment, Country, City, State, Postal Code, Region, Category, Sub-Category, Sales, Quantity, Discount, Profit]
# Index: []

# %% [markdown]
# ### Rows and Columns in our Dataset

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
## Rows and Columns in our Dataset

Shape = df.shape
print(Shape,'\n')

print('There are ' +str(df.shape[0]) + ' number of rows and ' + str(df.shape[1]) + ' columns in our dataset after removing Duplicates.')
# Out:
# (9977, 13)
#
# There are 9977 number of rows and 13 columns in our dataset after removing Duplicates.

# %% [markdown]
# ### Columns in our Dataset

# %%
## Columns in our Dataset

print('These are the columns in our dataset :\n')
for i in df.columns:
  print(i)

print('\n',df.columns)
# Out:
# These are the columns in our dataset :
#
# Ship Mode
# Segment
# Country
# City
# State
# Postal Code
# Region
# Category
# Sub-Category
# Sales
# Quantity
# Discount
# Profit
#
#  Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
## Information of Dataset Datatypes, null / non-null count and columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
## Some Statistical Information of Dataset

df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
## Null/Na/Nan count of Dataset

print(df.isna().sum())
print("\nAs we can see No Null value is present in our Dataset")
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64
#
# As we can see No Null value is present in our Dataset

# %%
## Datatypes of Dataset

df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
## Correlation in Dataset

df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %% [markdown]
# ### Analyzing Dataset across Columns to get Insight

# %%
## Columns in Dataset

df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ### Distrubution channel is <u>Superstore</u> according to our Dataset

# %% [markdown]
# ### Country

# %%
## Country

print(df['Country'].unique(),'\n')

print('Retail Business is Situated only in: ' + '\n' + str(
df['Country'].unique()[0]) )
# Out:
# ['United States']
#
# Retail Business is Situated only in:
# United States

# %% [markdown]
# ### Region involved in Retail dataset in United State

# %%
## Region involved in Retail dataset in United State

Regions = df['Region'].unique()
print(Regions,'\n')

print('United State Regions involved in our Retail Dataset are :','\n')
for i in Regions:
  print(i)


## Plotting Countplot for Region
sns.set_style('whitegrid') 
sns.countplot(x = df['Region'],order = df['Region'].value_counts().index, edgecolor = 'k', linewidth = 1)
plt.xlabel('Region', fontsize = 20)
plt.ylabel('Count', fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()
# Out:
# ['South' 'West' 'Central' 'East']
#
# United State Regions involved in our Retail Dataset are :
#
# South
# West
# Central
# East

# %% [markdown]
# ### Shipping Mode for above Regions

# %%
## Shipping Mode for above Regions

Ship_Mode = df['Ship Mode'].unique()
print(Ship_Mode,'\n')

print('Shipping Modes for Regions ' + str(Regions) +  ' are as follows :','\n')

for i in Ship_Mode:
  print(i)

## Plotting Countplot for Ship Mode
sns.countplot(data=df, x="Ship Mode",order = df['Ship Mode'].value_counts().index, edgecolor = 'k', linewidth = 1)
plt.xlabel('Ship Mode', fontsize = 20)
plt.ylabel('Count', fontsize = 20)
plt.xticks(Rotation = 45, fontsize = 12)
plt.yticks(fontsize = 15)
plt.show()
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
#
# Shipping Modes for Regions ['South' 'West' 'Central' 'East'] are as follows :
#
# Second Class
# Standard Class
# First Class
# Same Day
# C:\Users\Kamble\AppData\Local\Temp/ipykernel_15036/4244192418.py:15: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.xticks(Rotation = 45, fontsize = 12)

# %% [markdown]
# ### Retail Industry is Segmented by

# %%
## Retail Industry is Segmented by 

Segments = df['Segment'].unique()
print(Segments ,'\n')

print('Retail Industry is Segmented by ','\n')

for i in Segments:
  print(i)

## Plotting Countplot for Segment
sns.countplot(data=df, x="Segment", edgecolor = 'k', linewidth = 1)
plt.xlabel('Segment', fontsize = 20)
plt.ylabel('Count', fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()
# Out:
# ['Consumer' 'Corporate' 'Home Office']
#
# Retail Industry is Segmented by
#
# Consumer
# Corporate
# Home Office

# %% [markdown]
# ### States Covered in this Retail Industry according to our Dataset

# %%
## States Covered in this Retail Industry according to our Dataset

print('States Covered in this Retail Industry :','\n')
States = df['State'].unique()
print(States , '\n')

print('In total there are ' , len(States) , ' States involved for Distrubution or for Sales')


## Plotting Countplot for States

plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
sns.set_style('whitegrid') 
sns.countplot(x = df['State'], order = df['State'].value_counts().index, edgecolor ='k')
plt.xlabel('State', fontsize = 20)
plt.ylabel('Count', fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()
# Out:
# States Covered in this Retail Industry :
#
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']
#
# In total there are  49  States involved for Distrubution or for Sales

# %% [markdown]
# ### Total Cities involved

# %%
Cities = df['City'].unique()
print('In total there are ' , len(Cities) , ' Cities involved for Distrubution or for Sales')
# Out:
# In total there are  531  Cities involved for Distrubution or for Sales

# %% [markdown]
# ### Retail Categories :

# %%
Categories = df['Category'].unique()
print(Categories, '\n')

print('Retail Categories are :' ,'\n')
for i in Categories:
    print(i)
   
## Plotting Countplot for Categories 
sns.set_style('darkgrid') 
sns.countplot(x = df['Category'], order = df['Category'].value_counts().index, edgecolor = 'k', linewidth = 1)
plt.xlabel('Category', fontsize = 20)
plt.ylabel('Count', fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()
# Out:
# ['Furniture' 'Office Supplies' 'Technology']
#
# Retail Categories are :
#
# Furniture
# Office Supplies
# Technology

# %% [markdown]
# ### Sub-Categories

# %%
## Sub-Categories

Sub_Categories = df['Sub-Category'].unique()
print(Sub_Categories, '\n')

print('Sub-Categories are :' ,'\n')
for i in Sub_Categories:
    print(i)

print()
print('In total there are ', len(Sub_Categories) ,' Sub-Categories')

## Plotting Countplot for Sub-Categories 

sns.set_style('darkgrid')
plt.figure(figsize = (18,5))
sns.countplot(x = df['Sub-Category'], order = df['Sub-Category'].value_counts().index, edgecolor = 'k')
plt.xlabel('Sub-Category', fontsize = 18)
plt.ylabel('Sales', fontsize = 18)
plt.title('Sub-Category wise Sales', fontsize=25)
plt.xticks(rotation=90, fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()
# Out:
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']
#
# Sub-Categories are :
#
# Bookcases
# Chairs
# Labels
# Tables
# Storage
# Furnishings
# Art
# Phones
# Binders
# Appliances
# Paper
# Accessories
# Envelopes
# Fasteners
# Supplies
# Machines
# Copiers
#
# In total there are  17  Sub-Categories

# %% [markdown]
# ### Comparision of Datasets

# %%
display(df)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### Region wise Sales Overrview

# %%
sales_region = df[['Region','Sales']]


sales_region.groupby("Region").sum().sort_values(by = 'Sales', ascending=False).plot(kind="bar", figsize=(15,5), color = 'Orange' , edgecolor = 'k')
plt.title('Region wise Sales Overrview', fontsize = 20)
plt.xlabel('Regions', fontsize = 18)
plt.ylabel('Sales', fontsize = 18)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

print('From Visualisation we can say :','\n')
print('West Region have Sales High Compare to Other Regions')
# Out:
# From Visualisation we can say :
#
# West Region have Sales High Compare to Other Regions

# %% [markdown]
# ### Sales Overview By State

# %%
## Sales By State

sales_states = df[['State','Sales']]

sales_states.groupby("State").sum().sort_values(by = 'Sales', ascending=False).plot(kind="bar", figsize=(25,8), color='Purple')

plt.title('State wise Sales Overrview', fontsize = 23)
plt.xlabel('State', fontsize = 20)
plt.ylabel('Sales', fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

print('From Visualisation we can say :','\n')
print('Sales in California State is High Compare to Other States')
# Out:
# From Visualisation we can say :
#
# Sales in California State is High Compare to Other States

# %% [markdown]
# ### Category wise Sales

# %%
## Category wise Sales

plt.figure(figsize=(12,6))
plt.xlabel('Category', fontsize = 17)
plt.ylabel('Sales', fontsize = 17)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 12)
plt.title('Category wise Sales', fontsize = 20)
sns.set_style('whitegrid') 
sns.barplot(x=df['Category'], y=df['Sales'], edgecolor = 'k')


print('Technology Category Sales is High')
# Out:
# Technology Category Sales is High

# %% [markdown]
# ### Sub-Category Sales

# %%
## Sub-Category Sales

plt.figure(figsize=(15,6))
plt.xlabel('Sub-Category', fontsize = 20)
plt.ylabel('Sales', fontsize = 20)
plt.xticks(rotation=90, fontsize = 15)
plt.yticks(fontsize = 12)
plt.title('Sub-Category Sales', fontsize = 23)
sns.set_style('whitegrid') 
sns.barplot(x=df['Sub-Category'], y=df['Sales'], edgecolor = 'k')

print('We can see Copiers Sales is High')
# Out:
# We can see Copiers Sales is High

# %% [markdown]
# ### State wise Profit and Loss

# %%
## State wise Profit and Loss

plt.figure(figsize=(25,8))
plt.xlabel('State', fontsize = 20)
plt.ylabel('Profit', fontsize = 20)
plt.xticks(rotation=90, fontsize = 17)
plt.yticks(fontsize = 12)
plt.title('State wise Profit and Loss', fontsize = 23)
sns.set_style('whitegrid') 
sns.barplot(x=df['State'], y=df['Profit'])

print('State Vermount has Highest Profit')
# Out:
# State Vermount has Highest Profit

# %% [markdown]
# ### Sales of Top 10 Cities

# %%
## Sales of Top 10 Cities

top10 = df.groupby('City')['Sales'].sum().sort_values(ascending = False).iloc[0:10]

plt.figure(figsize=(15,6))
plt.title('Sales of Top 10 Cities', fontsize = 20)
plt.xlabel('City', fontsize = 20)
plt.ylabel('Total sum of Sales', fontsize = 18)
plt.xticks(rotation=90, fontsize = 16)
plt.yticks(fontsize = 15)
top10.plot(kind='bar', color = 'Violet', edgecolor = 'k')


print('We can see New York City has Highest Sales Value')
# Out:
# We can see New York City has Highest Sales Value

# %% [markdown]
# ### Discount

# %%
## Discount

#discount = df['Discount'].value_counts()
discount = df.groupby('City')['Discount'].value_counts().sort_values(ascending = False).iloc[0:10]
discount
# Out:
# City           Discount
# New York City  0.0         649
# Los Angeles    0.0         465
# San Francisco  0.0         332
# Philadelphia   0.2         325
# Seattle        0.0         285
# Los Angeles    0.2         267
# Houston        0.2         208
# New York City  0.2         180
# Chicago        0.2         178
# San Francisco  0.2         158
# Name: Discount, dtype: int64

# %% [markdown]
# ### Statewise Sales and Profit overview

# %%
## Statewise Sales and Profit overview

overview = df.groupby('State')['Profit','Sales'].sum()
overview.plot(kind='bar',figsize=(27,8))
plt.xlabel('State', fontsize = 20)
plt.ylabel('Profit and Sales', fontsize = 20)
plt.xticks(rotation=90, fontsize = 18)
plt.yticks(fontsize = 15)
plt.title('Sales and Profit overview', fontsize = 23)
plt.show()
# Out:
# C:\Users\Kamble\AppData\Local\Temp/ipykernel_15036/2408619586.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   overview = df.groupby('State')['Profit','Sales'].sum()

# %% [markdown]
# ### Comparing between Segments, Sales, Quantity and Discount

# %%
## Comparing between Segments, Sales, Quantity and Discount

sgm_dsct = df.groupby([(df['Segment']=='Consumer' ),(df['Segment']=='Corporate'),(df['Segment']=='Home Office'),'Discount']).sum()
sgm_dsct
# Out:
#                                   Postal Code        Sales  Quantity  \
# Segment Segment Segment Discount
# False   False   True    0.00         46948846  196470.1100      3389
#                         0.10           328098    8470.8810        65
#                         0.15           832793    4813.3970        34
#                         0.20         36981347  145645.0960      2305
#                         0.30          2250190   16833.9710       152
#                         0.32           308164    1305.4640        10
#                         0.40          1110144   15228.1440       140
#                         0.45            67228     854.4745         5
#                         0.50           711071   27978.1700        53
#                         0.60          1738634    1418.4040        78
#                         0.70          3312236    8637.6510       296
#                         0.80          3314386    1636.9220       205
# ...

# %%
print('\nWe can see frequency for ( 0.0 , 0.2 ) Discount has given better Sales per Quantity')

print('\nProfit is More in Consumer and Coporate Segment')
# Out:
# We can see frequency for ( 0.0 , 0.2 ) Discount has given better Sales per Quantity
#
# Profit is More in Consumer and Coporate Segment

# %%
pd.crosstab(df['Segment'], df.Region).plot(kind='bar',figsize=(25,8))

plt.title('Segmentwise Sales for each Region', fontsize = 25)
plt.ylim(0,2250)
plt.legend(df.Region ,borderpad=2, fontsize=20)
plt.xlabel('Segment', fontsize = 20)
plt.ylabel('Sales', fontsize = 20)
plt.xticks(rotation=90, fontsize = 20)
plt.yticks(fontsize = 15)
plt.show()

# %%
pd.crosstab(df['Category'], df.Region).plot(kind='bar',figsize=(25,8))
plt.title('Category Sales for each Region', fontsize = 25)
plt.xlabel('Category', fontsize = 20)
plt.ylabel('Sales', fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 15)
plt.legend(borderpad=2, fontsize=20)
plt.show()

# %%
pd.crosstab(df['Sub-Category'], df.Region).plot(kind='line',figsize=(25,8) , linewidth=4.0)
plt.title('Sub-Category Sales for each Region', fontsize = 25)
plt.xlabel('Sub-Category', fontsize = 20)
plt.ylabel('Sales', fontsize = 20)
plt.xticks(rotation=90, fontsize = 20)
plt.yticks(fontsize = 15)
plt.legend(borderpad=2, fontsize=20)
plt.show()

# %%
pd.crosstab(df['Discount'], df.Region).plot(kind='line',figsize=(25,8), linewidth=4.0)
plt.title('Sales for each Discount Regionwise', fontsize = 25)
plt.xlabel('Discount', fontsize = 20)
plt.ylabel('Sales', fontsize = 20)
plt.xticks(rotation=90, fontsize = 20)
plt.yticks(fontsize = 15)
plt.legend(df.Region, borderpad=2, fontsize=20)
plt.show()

# %% [markdown]
# ### Conclusion:
# 1. Profit is Good for 0.2 Discount and our Profit Drops after 0.3 and also gives Negative profit.
# 2. Segmentwise Consumer have higest Sales if given discount to this segment better sales can be hope.
# 3. Office supplies is good for sale can can be work good
